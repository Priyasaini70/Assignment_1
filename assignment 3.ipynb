# %%
# Question 1. Create a class named Student with attributes:
#name
#age
# course

#Create an object and print all the details.
class Student:
    Name="priya"
    Age=19
    course="B.Tech"
st=Student()          # creation of object
print("My name is :",st.Name)
print("My age is :",st.Age)
print("Course :",st.course)
# Out:
# My name is : priya
# My age is : 19
# Course : B.Tech

# %%
# Question 2. Create a class named Car with attributes:
#brand
#model
#price

#Create two objects and display their details.
class Car:

    def __init__(self,brand,model,price):
        self.brand=brand
        self.model=model
        self.price=price

    def display(self):
        print("car brand:",self.brand)
        print("car model:",self.model)
        print("car price:",self.price)

car1 =Car("Toyota","fortuner",3000000)  # object 1
car2=Car("Hyundai","Creta",2000000)     # object 2

car1.display()
car2.display()
# Out:
# car brand: Toyota
# car model: fortuner
# car price: 3000000
# car brand: Hyundai
# car model: Creta
# car price: 2000000

# %%
#Question 3. Create a class named Employee and use a constructor (init) to initialize:
#employee_id
#name
#salary

#Print the employee details.
class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def disp(self):
        print("Employee id =", self.employee_id)
        print("Employee name =", self.name)
        print("Employee salary =", self.salary)

emp1 = Employee(101, "raj", 400000)
emp2 = Employee(201, "Ram", 500000)

emp1.disp()
emp2.disp()
# Out:
# Employee id = 101
# Employee name = raj
# Employee salary = 400000
# Employee id = 201
# Employee name = Ram
# Employee salary = 500000

# %%
#Question 4. Create a class named Rectangle with attributes:
#length
#width

#Create a method to calculate and print the area of the rectangle.
class Rectangle:
    def __init__(self,length,width):
        self.length =length
        self.width = width
    def area(self):

        print ("Area of Rectangle:",self.length*self.width)

R1=Rectangle(10,4)        
R1.area()
# Out:
# Area of Rectangle: 40

# %%
# Question 5. Create a class named Circle with an attribute radius.
#Create a method that calculates and prints the area of the circle.
  
class Circle:
    def __init__(self,radius):
        self.radius=radius

    def Area(self):
        A1=("Area of Circle is :",2*3.14*self.radius) 
        print(A1)  
         
Circle1= Circle( 7)   
print("Area of circle")

Circle1.Area()
# Out:
# Area of circle
# ('Area of Circle is :', 43.96)

# %%
#Question 6. Create a class named BankAccount with:account_holder, balance
#Create methods:
#deposit(amount)
#withdraw(amount)

#Display the updated balance after each transaction.
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance = self.balance + amount
        print("Balance after deposit:", self.balance)

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance = self.balance - amount
            print("Balance after withdrawal:", self.balance)
        else:
            print("Insufficient balance")

name = input("Enter account holder name: ")
balance = float(input("Enter initial balance: "))

acc = BankAccount(name, balance)

amount = float(input("Enter deposit amount: "))
acc.deposit(amount)

amount = float(input("Enter withdrawal amount: "))
acc.withdraw(amount)

# %%
#Question 7. Create a class named Animal with a method sound().
#Create a child class Dog that overrides the sound() method and prints "Bark".
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

d = Dog()    #object of Dog class

d.sound()
# Out:
# Bark

# %%
#Question 8. Create a class named Person with attributes:name, age
#Create a child class Student with an additional attribute:roll_number
#Display all the details using an object of the Student class. 
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, roll_number):
        super().__init__(name, age)
        self.roll_number = roll_number

    def disp(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Roll Number:", self.roll_number)

name = input("Enter name: ")
age = int(input("Enter age: "))
roll = input("Enter roll number: ")

s = Student(name, age, roll)   # object
print("Details")
s.disp()
# Out:
# Details
# Name: Raj
# Age: 21
# Roll Number: 34

# %%
#Question 9. Create a class named Calculator with methods:add(),subtract() , multiply(), divide()
#Take two numbers as input and perform all operations.
class Calculator:
    def add(self, a, b):
        print("Addition:", a + b)

    def subtract(self, a, b):
        print("Subtraction:", a - b)

    def multiply(self, a, b):
        print("Multiplication:", a * b)

    def divide(self, a, b):
            print("Division:", a / b)

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

c = Calculator()
print("operations Results:")
c.add(num1, num2)
c.subtract(num1, num2)
c.multiply(num1, num2)
c.divide(num1, num2)
# Out:
# operations Results:
# Addition: 12.0
# Subtraction: 8.0
# Multiplication: 20.0
# Division: 5.0

# %%
#Question 10. Create a class named LibraryBook with attributes:book_name,author,price
#Create a method display_book_info() that prints all book details. Create at least three book objects and display their information.
class LibraryBook:
    def __init__(self, book_name, author, price):
        self.book_name = book_name
        self.author = author
        self.price = price

    def display_book_info(self):
        print("Book Name:", self.book_name)
        print("Author:", self.author)
        print("Price:", self.price)
        print()

book1 = LibraryBook("Python Basics", "John Smith", 350)
book2 = LibraryBook("Data Science", "Priya Sharma", 450)
book3 = LibraryBook("Machine Learning", "Rahul Verma", 550)

print("Display book information:")
book1.display_book_info()
book2.display_book_info()
book3.display_book_info()
# Out:
# Display book information:
# Book Name: Python Basics
# Author: John Smith
# Price: 350
#
# Book Name: Data Science
# Author: Priya Sharma
# Price: 450
#
# Book Name: Machine Learning
# Author: Rahul Verma
# Price: 550
